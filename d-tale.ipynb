# %% [markdown]
#  Dtale: D-Tale combines a Flask back-end and a React front-end to provide an easy-to-use interface for viewing and analyzing Pandas data structures. It integrates with ipython notebooks and python/ipython terminals seamlessly. This tool currently supports the following Pandas objects: DataFrame, Series, MultiIndex, DatetimeIndex, and RangeIndex. As with Pandas profiling, it supports a variety of visualizations, including heatmaps, charts, and three-dimensional plots.

# %%
# load Affairs dataset from statsmodels
# https://www.statsmodels.org/stable/datasets/generated/fair.html
# https://www.statsmodels.org/stable/datasets/index.html#datasets


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# Load data
data = sm.datasets.fair.load_pandas().data
data.head()
#is data loaded as dataframe?
#type(data)
# Out:
#    rate_marriage   age  yrs_married  children  religious  educ  occupation  \
# 0            3.0  32.0          9.0       3.0        3.0  17.0         2.0
# 1            3.0  27.0         13.0       3.0        1.0  14.0         3.0
# 2            4.0  22.0          2.5       0.0        1.0  16.0         3.0
# 3            4.0  37.0         16.5       4.0        3.0  16.0         5.0
# 4            5.0  27.0          9.0       1.0        1.0  14.0         3.0
#
#    occupation_husb   affairs
# 0              5.0  0.111111
# 1              4.0  3.230769
# 2              5.0  1.400000
# 3              5.0  0.727273
# 4              4.0  4.666666

# %%
#!pip3 install dtale
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 7.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.7/642.7 kB 17.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 24.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 MB 20.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 4.8 MB/s eta 0:00:00
# ...

# %%
# perform EDA with D-tale
import dtale
dtale.show(data)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://talca-dhcp-wireless-172.16.58.249.in.utalca.cl:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # d-tale documentation
# https://pypi.org/project/dtale/
