# %% [markdown]
# Here's an example where we use the Breast Cancer Wisconsin (Diagnostic) dataset from the sklearn.datasets module. We'll perform dimensionality reduction using PCA and t-SNE.
#
# Step 1: Import the necessary libraries and load the dataset.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.datasets import load_breast_cancer

# Load the Breast Cancer Wisconsin dataset
cancer = load_breast_cancer()
X = cancer.data
y = cancer.target

# %% [markdown]
# Step 2: Apply PCA for dimensionality reduction.

# %%
# Initialize and fit PCA
pca = PCA(n_components=2)  # Set the desired number of components
X_pca = pca.fit_transform(X)

# Plot the results
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.title('PCA - Breast Cancer Dataset')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %% [markdown]
# Step 3: Apply t-SNE for dimensionality reduction.

# %%
# Initialize and fit t-SNE
tsne = TSNE(n_components=2, random_state=42)  # Set the desired number of components
X_tsne = tsne.fit_transform(X)

# Plot the results
plt.figure(figsize=(8, 6))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='viridis')
plt.title('t-SNE - Breast Cancer Dataset')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()

# %% [markdown]
# Feel free to run the code and visualize the reduced representations obtained from PCA and t-SNE for the Breast Cancer Wisconsin dataset. You can also modify the code to explore other datasets of interest by using the appropriate dataset from sklearn.datasets and adjusting the plotting labels accordingly.
